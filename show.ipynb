# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
df = pd.concat([pd.read_csv('./result/result/metric_trace_result_valid.csv'),
pd.read_csv('./result/result/metric_trace_result.csv')])
df.columns.values
# Out:
# array(['For_catalogue_latency', 'Rec_catalogue_latency',
#        'Act_catalogue_latency', 'Score_catalogue_latency',
#        'For_cpu_usage_carts', 'Rec_cpu_usage_carts',
#        'Act_cpu_usage_carts', 'Score_cpu_usage_carts',
#        'For_cpu_usage_carts_db', 'Rec_cpu_usage_carts_db',
#        'Act_cpu_usage_carts_db', 'Score_cpu_usage_carts_db',
#        'For_cpu_usage_catalogue', 'Rec_cpu_usage_catalogue',
#        'Act_cpu_usage_catalogue', 'Score_cpu_usage_catalogue',
#        'For_cpu_usage_catalogue_db', 'Rec_cpu_usage_catalogue_db',
#        'Act_cpu_usage_catalogue_db', 'Score_cpu_usage_catalogue_db',
#        'For_cpu_usage_ip6', 'Rec_cpu_usage_ip6', 'Act_cpu_usage_ip6',
#        'Score_cpu_usage_ip6', 'For_cpu_usage_ip7', 'Rec_cpu_usage_ip7',
#        'Act_cpu_usage_ip7', 'Score_cpu_usage_ip7', 'For_cpu_usage_orders',
#        'Rec_cpu_usage_orders', 'Act_cpu_usage_orders',
#        'Score_cpu_usage_orders', 'For_cpu_usage_orders_db',
# ...

# %%
plt.figure(figsize=(20,20), dpi=80)

ax1 = plt.subplot(10,1,1)
plt.plot(df['Act_cpu_usage_carts_db'].values)
for i in range(len(df)):
    if df['Pred_Global'].values[i] == 1:
        plt.axvspan(xmin=i-1,xmax=i+1,facecolor="r",alpha=0.1)

ax2 = plt.subplot(10,1,2)
plt.plot(df['Act_cpu_usage_ip6'].values)
for i in range(len(df)):
    if df['Pred_Global'].values[i] == 1:
        plt.axvspan(xmin=i-1,xmax=i+1,facecolor="r",alpha=0.1)

ax3 = plt.subplot(10,1,3)
plt.plot(df['Act_cpu_usage_ip7'].values)
for i in range(len(df)):
    if df['Pred_Global'].values[i] == 1:
        plt.axvspan(xmin=i-1,xmax=i+1,facecolor="r",alpha=0.1)

ax4 = plt.subplot(10,1,4)
plt.plot(df['Act_frontend_latency'].values)
for i in range(len(df)):
    if df['Pred_Global'].values[i] == 1:
        plt.axvspan(xmin=i-1,xmax=i+1,facecolor="r",alpha=0.1)
        
ax5 = plt.subplot(10,1,5)
plt.plot(df['Act_mem_usage_catalogue'].values)
for i in range(len(df)):
    if df['Pred_Global'].values[i] == 1:
        plt.axvspan(xmin=i-1,xmax=i+1,facecolor="r",alpha=0.1)

ax6 = plt.subplot(10,1,6)
plt.plot(df['Act_mem_usage_front_end'].values)
for i in range(len(df)):
    if df['Pred_Global'].values[i] == 1:
        plt.axvspan(xmin=i-1,xmax=i+1,facecolor="r",alpha=0.1)
        
ax7 = plt.subplot(10,1,7)
plt.plot(df['Act_shipping_latency'].values)
for i in range(len(df)):
    if df['Pred_Global'].values[i] == 1:
        plt.axvspan(xmin=i-1,xmax=i+1,facecolor="r",alpha=0.1)

ax8 = plt.subplot(10,1,8)
plt.plot(df['Act_root -> orders'].values)
for i in range(len(df)):
    if df['Pred_Global'].values[i] == 1:
        plt.axvspan(xmin=i-1,xmax=i+1,facecolor="r",alpha=0.1)
        
ax9 = plt.subplot(10,1,9)
plt.plot(df['Act_orders -> payment'].values)
for i in range(len(df)):
    if df['Pred_Global'].values[i] == 1:
        plt.axvspan(xmin=i-1,xmax=i+1,facecolor="r",alpha=0.1)

ax10 = plt.subplot(10,1,10)
plt.plot(df['Act_orders -> user'].values)
for i in range(len(df)):
    if df['Pred_Global'].values[i] == 1:
        plt.axvspan(xmin=i-1,xmax=i+1,facecolor="r",alpha=0.1)
        
plt.savefig('./show.png')
